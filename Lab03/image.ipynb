# %% [markdown]
# # Bai01
# ![image.png](attachment:image.png)
# ## Result
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Bai02
# ![image.png](attachment:image.png)
# ## Result
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Bai 03
# ![image.png](attachment:image.png)
# ## Result
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Bai04
# ![image.png](attachment:image.png)
# ## Result
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Bai05
# ![image.png](attachment:image.png)
# ## Result
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Bai06
# ![image-2.png](attachment:image-2.png)
# ## Result
# ![image.png](attachment:image.png)

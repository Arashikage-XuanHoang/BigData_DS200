# %% [markdown]
# # Bài 01
# ![image.png](attachment:image.png)
# Kết quả
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Bài 02
# ![image.png](attachment:image.png)
#
# Kết quả
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Bài 03
# ![image.png](attachment:image.png)
# Kết quả
# ![image-2.png](attachment:image-2.png)

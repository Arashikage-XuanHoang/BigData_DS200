# %% [markdown]
# # Bai01
# ![image.png](attachment:image.png)

# %% [markdown]
# # Bai 02
# ![image.png](attachment:image.png)

# %% [markdown]
# # Bai 03
# ![image.png](attachment:image.png)

# %% [markdown]
# # Bai 04
# ![image.png](attachment:image.png)

# %% [markdown]
# # Bai01
# ![image.png](attachment:image.png)

# %% [markdown]
# # Bai 02
# ![image.png](attachment:image.png)

# %% [markdown]
# # Bai 03
# ![image.png](attachment:image.png)

# %% [markdown]
# # Bai 04
# ![image.png](attachment:image.png)

# %% [markdown]
# # Bai 05
# ![image.png](attachment:image.png)
# ## Result
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Bai06
# ![image.png](attachment:image.png)
# ## Result
